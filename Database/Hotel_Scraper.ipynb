# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import numpy as np
import csv
import json
print('All required libraries have been successfully imported.')
# Out:
# All required libraries have been successfully imported.

# %%
# hotel_full_urllist = pd.read_csv("Project-Dataset/jaipur_hotel_urls.txt")
with open('Project-Dataset/hotel urls/Jaipur_hotel_urls.txt', newline='') as f:
    reader = csv.reader(f)
    hotel_full_urllist = list(reader)
# print(hotel_full_urllist)
with open('Project-Dataset/hotel urls/Jaipur_hotels.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data = data[1:]
print(len(hotel_full_urllist))
print('Hotel urls CSV file read successfully..')
# Out:
# 300
# Hotel urls CSV file read successfully..

# %%
length_df = int(len(hotel_full_urllist))
hotel_info = []
for iter_val in range(length_df):
    print(iter_val)
    try:
        url = str(hotel_full_urllist[iter_val])[2:-2]
        html_text = requests.get(url).text
        soup = BeautifulSoup(html_text, 'lxml')

        # BASIC INFO
        div1 = soup.find("div", class_ = "uitk-spacing uitk-spacing-padding-large-inlineend-three uitk-layout-grid-item uitk-layout-grid-item-columnspan-small-1 uitk-layout-grid-item-columnspan-medium-1 uitk-layout-grid-item-columnspan-large-8")

        div2 = div1.find('div', class_ = "uitk-spacing uitk-spacing-padding-small-blockend-four uitk-spacing-padding-large-blockstart-three")
        hotel_id = data[iter_val][0]
        
        hotel_name = div2.find('h1', class_ = "uitk-heading-3").text
        print(hotel_name)
        if(hotel_name!=data[iter_val][1]):
            print("Hotel names do not match!!")
        
            
        hotel_rating = div1.find('div', class_ = "uitk-spacing uitk-spacing-padding-blockend-six", attrs= {"data-stid":"content-hotel-reviewsummary"})
        try:
            overall_rating = hotel_rating.find('meta' , attrs= {"itemprop":"ratingValue"}).attrs['content']
            hotel_rating_overall_word = hotel_rating.find('meta' , attrs= {"itemprop":"description"}).attrs['content']
            hotel_review_count = hotel_rating.find('meta' , attrs= {"itemprop":"reviewCount"}).attrs['content']
        except:
            overall_rating = ''
            hotel_rating_overall_word =''
            hotel_review_count = ''
        try:    
            amenities_list = div1.find('ul', class_ = "uitk-layout-grid uitk-layout-grid-gap-four uitk-layout-grid-auto-flow-column uitk-layout-grid-columns-2 uitk-layout-grid-rows-3").find_all('li')
            amenities = []
            for amenity in amenities_list:
                amenities.append(amenity.text)
        except:
            continue
        
        location = soup.find('div', class_ = "uitk-spacing uitk-spacing-padding-large-blockend-six uitk-flex-item")

        address = location.find('div', class_ = "uitk-text uitk-type-300 uitk-flex-item uitk-flex-basis-full_width uitk-text-default-theme").text
        latitude = location.find('meta', itemprop = "latitude").attrs['content']
        longitude = location.find('meta', itemprop = "longitude").attrs['content']

        hotel_price = data[iter_val][2]
        
        # print(hotel_name)
        # print(overall_rating, hotel_rating_overall_word)
        # print(amenities)
        # print(address)
        # print(latitude)
        # print(longitude)
        # print(hotel_price)

        hotel_info1 = [hotel_id,hotel_name,overall_rating,hotel_rating_overall_word,amenities,address, 'Jaipur', 'India',latitude+", "+longitude,hotel_price]
        hotel_info.append(hotel_info1)
    except:
        continue
print("Batch- Collection successfully done..\n")
# Out:
# 0
# ITC Rajputana, A Luxury Collection Hotel, Jaipur
# 1
# Jaipur Marriott Hotel
# 2
# Hilton Jaipur
# 3
# Trident, Jaipur
# 4
# The Oberoi Rajvilas
# 5
# Umaid Bhawan - A Heritage Style Boutique Hotel
# 6
# Radisson Jaipur City Center
# 7
# Umaid Mahal - A Heritage Style Boutique Hotel
# 8
# Four Points by Sheraton Jaipur, City Square
# 9
# Devi Ratn, Jaipur -IHCL SeleQtions
# 10
# 5 BY OYO METROPOLITAN
# 11
# Radisson Blu Jaipur
# 12
# Crowne Plaza Jaipur Tonk Road, an IHG Hotel
# 13
# Indana Palace Jaipur
# 14
# Royal Heritage Haveli
# 15
# Umaid Haveli Hotel & Resorts
# 16
# Narain Niwas Palace
# 17
# Pearl Palace Heritage
# 18
# Ramada by Wyndham Jaipur
# 19
# Hotel 360
# 20
# Tree of Life Chhota Mahal, Amer, Jaipur
# 21
# Vesta International
# 22
# Hotel Triveni Residency
# 23
# Hotel Empire Regency
# 24
# The Fern Residency Jaipur
# 25
# Dera Rawatsar - Heritage Hotel
# 26
# ITC Rajputana, A Luxury Collection Hotel, Jaipur
# 27
# Jaipur Marriott Hotel
# 28
# Ramada by Wyndham Jaipur North
# 29
# Crowne Plaza Jaipur Tonk Road, an IHG Hotel
# 30
# Zone by The Park Bani Park Jaipur
# 31
# Barwara Kothi
# 32
# Hilton Jaipur
# 33
# Royal Orchid Central Jaipur
# 34
# ibis Jaipur Civil Lines Hotel
# 35
# County Inn Hotel
# 36
# Crimson Park - The Heritage
# 37
# Hotel Cordon Vay
# 38
# Hotel Royal Empire
# 39
# Hotel Royal Orchid
# 40
# Sanskar Prime Hotel
# 41
# Khandwa Haveli
# 42
# Khas Bagh
# 43
# Sarovar Portico Jaipur
# 44
# Royal View Hotel
# 45
# hotel S57
# 46
# Hotel Gandharva - A Green Hotel
# 47
# Jaipur Hotel New
# 48
# Four Points by Sheraton Jaipur, City Square
# 49
# Treebo Trend Airport View
# 50
# Treebo Trend Hotel New Rockwell
# 51
# Hotel Vrisa
# 52
# Ramada by Wyndham Jaipur Jaisinghpura
# 53
# Treebo Trend Resolute
# 54
# Lords Plaza, Jaipur
# 55
# Hotel Rajlaxmi Palace
# 56
# KK Royal Hotel & Convention Centre
# 57
# Hotel Istana Inn
# 58
# Hotel Marigold Jaipur
# 59
# Villa 243
# 60
# Jasoda Heritage by Keshav Global Hotels
# 61
# Umaid Bhawan
# 62
# Khatu Haveli
# 63
# Le Méridien Jaipur Resort & Spa
# Hotel names do not match!!
# 64
# Regenta Inn Jaipur
# 65
# Arya Niwas
# 66
# Mahal Rajwada Resort
# 67
# Hotel The Livin
# 68
# Rajputana Diaries
# 69
# Tara Niwas
# 70
# Castle Kanota
# 71
# OYO 35787 Hotel Lily Bay Prime
# 72
# Hotel The Grand Kukas
# 73
# Bara Bungalow Kalwar, Jaipur - A Rosakue Collection
# 74
# Hotel Rock land By Tuma Hotels
# 75
# Cambay Grand
# 76
# OYO 1049 Nirman Nagar
# 77
# Hotel Krishna Boutique Stay Jaipur
# 267
# Hotel Mansingh
# 268
# Hotel Shiv Palace
# 269
# Grand Kukas Residency
# 270
# Kailrugji - A City Centre Hotel
# 271
# Hotel Kalyan
# 272
# Hotel Stay Bridge
# 273
# Hotel Diggi Palace
# 274
# FabHotel 7 Nights
# 275
# Mark Inn by Black Tie
# 276
# Hotel Black Hole
# 277
# Hotel Madhav Palace
# 278
# Hotel Chinar
# 279
# Hotel Jaipur Central
# 280
# Anuraag Villa
# 281
# Hotel The Star Leaf Prime
# 282
# Hotel Sky Heights
# 283
# Jas Vilas
# 284
# FabHotel K Mahaveer
# 285
# FabHotel K Mahaveer
# 286
# Pink Elephant
# 287
# Neerja Inn
# 288
# The La Shivalika
# 289
# Hotel shekhawati jaipur
# 290
# Nokha House
# 291
# Nirbana Palace - A Heritage Hotel
# 292
# FabHotel Jaipur House
# 293
# Hotel Jaipur Heriatge
# 294
# Hotel Shree Residency
# 295
# Pandya Niwas
# 296
# Leisure Inn Grand Chanakya
# 297
# Chokhi Dhani Resort Jaipur
# 298
# Hotel De Nada
# 299
# Bara Bungalow Amer
# Batch- Collection successfully done..

# %%
def create_csv(fields, rows, dirname, filename):
    with open(dirname+filename, 'w', encoding='UTF8', newline='') as csvfile: 
        # creating a csv writer object
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(fields) 
        csvwriter.writerows(rows)
    print(f"Saved csv with name {filename}")

# %%
hoteloo = hotel_info
for i in range(len(hoteloo)):
    hoteloo[i].pop(6)
    break

# %%
fields = ['hotel_id', 'hotel_name', 'hotel_rating', 'hotel_experience', 'amenities', 'address', 'city', 'country', 'location', 'hotel_price']
create_csv(fields, hotel_info, "Project-Dataset/", "Jaipur_hotel_info.csv")
# with open('Project-Dataset/udaipur_hotel_info.csv', 'a', newline="") as csv_obj:
#     writer_obj = csv.writer(csv_obj)
#     for hotel in hotel_info:
#         writer_obj.writerow(hotel)
#     csv_obj.close()
print('Hotel Dataframe updated..')
# Out:
# Saved csv with name Jaipur_hotel_info.csv
# Hotel Dataframe updated..

# %%
def make_json(csvFilePath, jsonFilePath):

    # create a dictionary
    data = ""

    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)

        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:

            # Assuming a column named 'No' to
            # be the primary key
            
            data = data+'\n'
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data ,indent=1))

# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'Project-Dataset/hotel_info.csv'
jsonFilePath = r'Project-Dataset/hotel_info3.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)

# %%
hotel_info_df = pd.read_csv("Project-Dataset/hotel_info.csv")
for i in range(len(hotel_info_df)):
    hotel_info_df["amenities"][i] = hotel_info_df["amenities"][i].split(',')
    hotel_info_df["price"][i] = float(hotel_info_df["price"][i][1:])
print(hotel_info_df["price"],hotel_info_df["amenities"])
hotel_info_df.to_json("Project-Dataset/hotel_info2.json")
# Out:
# 0      97.0
# 1     115.0
# 2     349.0
# 3      97.0
# 4      93.0
# 5     101.0
# 6      86.0
# 7      93.0
# 8      27.0
# 9     278.0
# 10     63.0
# 11    479.0
# 12     85.0
# 13     94.0
# 14     97.0
# 15     51.0
# 16    121.0
# 17     46.0
# 18     72.0
# 19    208.0
# 20    115.0
# 21     38.0
# 22    142.0
# 23     82.0
# 24     94.0
# 25     36.0
# 26    101.0
# 27     17.0
# 28     85.0
# 29     97.0
# 30     45.0
# 31     37.0
# 32     50.0
# 33     51.0
# 34    115.0
# 35     53.0
# 36     47.0
# 37     90.0
# 38    153.0
# 39     58.0
# 40     32.0
# 41     44.0
# 42     33.0
# 43     35.0
# 44     78.0
# 45     60.0
# 46     13.0
# 47     29.0
# 48     38.0
# 49     47.0
# Name: price, dtype: object 0     [['Spa',  'Hot Tub',  'Free WiFi',  'Parking i...
# 1     [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 2     [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 3     [['Spa',  'Hot Tub',  'Free WiFi',  'Parking i...
# 4     [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 5     [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 6     [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 7     [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 8     [['Free WiFi',  'Parking included',  'Laundry'...
# 9     [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 10    [['Pool',  'Breakfast included',  'Free WiFi',...
# 11    [['Pool',  'Spa',  'Hot Tub',  'Free WiFi',  '...
# 12    [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 13    [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 14    [['Pool',  'Spa',  'Pet friendly',  'Free WiFi...
# 15    [['Pool',  'Breakfast included',  'Free WiFi',...
# 16    [['Free WiFi',  'Parking included',  'Laundry'...
# 17    [['Pool',  'Free WiFi',  'Parking included',  ...
# 18    [['Pool',  'Spa',  'Hot Tub',  'Free WiFi',  '...
# 19    [['Pool',  'Pet friendly',  'Free WiFi',  'Par...
# 20    [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 21    [['Pool',  'Free WiFi',  'Parking included',  ...
# 22    [['Pool',  'Spa',  'Breakfast included',  'Fre...
# 23    [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 24    [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 25    [['Pool',  'Free WiFi',  'Parking included',  ...
# 26    [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 27    [['Pet friendly',  'Free WiFi',  'Parking incl...
# 28    [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 29    [['Pool',  'Spa',  'Pet friendly',  'Free WiFi...
# 30    [['Pool',  'Free WiFi',  'Parking included',  ...
# 31    [['Pool',  'Free airport shuttle',  'Free WiFi...
# 32    [['Kitchen',  'Pet friendly',  'Free WiFi',  '...
# 33    [['Pool',  'Free WiFi',  'Parking included',  ...
# 34    [['Pool',  'Free WiFi',  'Parking included',  ...
# 35    [['Pool',  'Free WiFi',  'Parking included',  ...
# 36    [['Pool',  'Free WiFi',  'Parking included',  ...
# 37    [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 38    [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 39    [['Pool',  'Free airport shuttle',  'Breakfast...
# 40    [['Free WiFi',  'Parking included',  'Laundry'...
# 41    [['Free WiFi',  'Parking included',  'Laundry'...
# 42    [['Free WiFi',  'Parking included',  'Laundry'...
# 43    [['Spa',  'Free WiFi',  'Parking included',  '...
# 44    [['Spa',  'Free WiFi',  'Parking included',  '...
# 45    [['Pool',  'Spa',  'Free WiFi',  'Parking incl...
# 46    [['Free WiFi',  'Parking included',  'Laundry'...
# 47    [['Free WiFi',  'Parking included',  'Laundry'...
# 48    [['Free WiFi',  'Parking included',  'Laundry'...
# 49    [['Spa',  'Breakfast included',  'Free WiFi', ...
# Name: amenities, dtype: object
# C:\Users\admin\AppData\Local\Temp/ipykernel_3508/2130041846.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_info_df["amenities"][i] = hotel_info_df["amenities"][i].split(',')
# C:\Users\admin\AppData\Local\Temp/ipykernel_3508/2130041846.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_info_df["price"][i] = float(hotel_info_df["price"][i][1:])
